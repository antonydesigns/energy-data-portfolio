# %%
# Initial setup

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)
pd.options.display.float_format = "{:,.3f}".format

# rng = np.random.RandomState(24)

# %%
# Data quality inspection

# %%
df = pd.read_csv("./data/raw/generation_tech_2015.csv")

# %%
df
# Out:
#                                    MTU (CET/CEST)    Area Production Type  \
# 0       01/01/2015 00:00:00 - 01/01/2015 01:00:00  BZN|FR         Biomass
# 1       01/01/2015 01:00:00 - 01/01/2015 02:00:00  BZN|FR         Biomass
# 2       01/01/2015 02:00:00 - 01/01/2015 03:00:00  BZN|FR         Biomass
# 3       01/01/2015 03:00:00 - 01/01/2015 04:00:00  BZN|FR         Biomass
# 4       01/01/2015 04:00:00 - 01/01/2015 05:00:00  BZN|FR         Biomass
# ...                                           ...     ...             ...
# 183955  31/12/2015 19:00:00 - 31/12/2015 20:00:00  BZN|FR    Wind Onshore
# 183956  31/12/2015 20:00:00 - 31/12/2015 21:00:00  BZN|FR    Wind Onshore
# 183957  31/12/2015 21:00:00 - 31/12/2015 22:00:00  BZN|FR    Wind Onshore
# 183958  31/12/2015 22:00:00 - 31/12/2015 23:00:00  BZN|FR    Wind Onshore
# 183959  31/12/2015 23:00:00 - 01/01/2016 00:00:00  BZN|FR    Wind Onshore
#
#        Generation (MW)
# 0               193.00
# 1               193.00
# 2               193.00
# 3               193.00
# 4               193.00
# ...                ...
# 183955         3140.00
# 183956         3252.00
# 183957         3196.00
# 183958         2840.00
# 183959         2526.00
#
# [183960 rows x 4 columns]
